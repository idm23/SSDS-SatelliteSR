# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/MyDrive/SSDSResearchSP21
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/SSDSResearchSP21

# %%
# %run train.py --mode 'multi' --num_cond_channels 20 --batch_size 16 --num_epochs 1000 --lr 1e-4 --annealingRate 1e-3 --num_steps 16 --num_levels 3 --dset_fromFile True --resume True --coupling16 True --tight True

# %%
while True:pass
