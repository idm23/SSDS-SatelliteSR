# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/MyDrive/SSDSResearchSP21
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/SSDSResearchSP21

# %%
import numpy as np
from sklearn.manifold import TSNE

training_dset = np.load('dota_np/train_cond_x_list_0.npy').reshape(13154, -1)
print(np.shape(training_dset))
# Out:
# (13154, 81920)

# %%
dset_embedded = TSNE(n_components=2, verbose = 1).fit_transform(training_dset) # Works but takes ages
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 13154 samples in 264.144s...
# [t-SNE] Computed neighbors for 13154 samples in 22878.962s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 13154
# [t-SNE] Computed conditional probabilities for sample 2000 / 13154
# [t-SNE] Computed conditional probabilities for sample 3000 / 13154
# [t-SNE] Computed conditional probabilities for sample 4000 / 13154
# [t-SNE] Computed conditional probabilities for sample 5000 / 13154
# [t-SNE] Computed conditional probabilities for sample 6000 / 13154
# [t-SNE] Computed conditional probabilities for sample 7000 / 13154
# [t-SNE] Computed conditional probabilities for sample 8000 / 13154
# [t-SNE] Computed conditional probabilities for sample 9000 / 13154
# [t-SNE] Computed conditional probabilities for sample 10000 / 13154
# [t-SNE] Computed conditional probabilities for sample 11000 / 13154
# [t-SNE] Computed conditional probabilities for sample 12000 / 13154
# ...

# %%
np.save('tsne.npy', dset_embedded)
